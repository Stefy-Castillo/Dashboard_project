# %% [markdown]
# # 1. Librerias

# %%
import pandas as pd

# %% [markdown]
# # 2. Importamos CSV

# %%
ruta_archivo_csv = '../01_data/datos_locales_coordenadas.csv'

df_locales = pd.read_csv(ruta_archivo_csv)

df_locales.head(5)
# Out:
#                       local                               direccion  \
# 0  Teatro Príncipe Gran Vía  C. de las Tres Cruces, 8, 28013 Madrid
# 1      El Golfo Comedy Club     C. de las Huertas, 57, 28014 Madrid
# 2  Teatro Arlequín Gran Vía     C. de San Bernardo, 5, 28013 Madrid
# 3   Teatro Capitol Gran Vía           C/ Gran Vía, 41, 28013 Madrid
# 4         Estación Malasaña            C. del Pez, 16, 28004 Madrid
#
#         tipo_local  valoracion_google  numero_reseñas_google  \
# 0           teatro                4.2                   2601
# 1  club de comedia                4.7                   1082
# 2           teatro                4.2                   5264
# 3           teatro                4.2                   4902
# 4              bar                4.5                    344
#
#                              enlace_web                         coordenadas
# 0  http://www.teatroprincipegranvia.es/            (40.4195185, -3.7026612)
# ...

# %%
df_locales
# Out:
#                                            local  \
# 0                       Teatro Príncipe Gran Vía
# 1                           El Golfo Comedy Club
# 2                       Teatro Arlequín Gran Vía
# 3                        Teatro Capitol Gran Vía
# 4                              Estación Malasaña
# 5                                 Teatro Alcázar
# 6                              Cinesa Fuencarral
# 7                      El Sombrerero Comedy Club
# 8                            Teatro de las Aguas
# 9                                      Abonavida
# 10                                  Beer Station
# 11                               Teatros Luchana
# 12             Pequeño Teatro Gran Vía de Madrid
# 13                                       The Mun
# 14            Gran teatro Caixabank Príncipe Pío
# 15                                 Estupenda Bar
# 16      Teatro Chocita del Loro - Avenida Brasil
# 17                         Teatro Reina Victoria
# ...

# %% [markdown]
# # 3. Nueva clasificación locales

# %%
# Diccionario de clasificación
clasificacion = {
    'Estupenda Bar': 'bar espectaculos',
    'Collage Burlesque': 'bar espectaculos',
    'Tropicana Beach Club Madrid': 'bar espectaculos',
    'Intruso Bar': 'bar espectaculos',
    'Sala Kathedral': 'bar espectaculos',
    'La Nota Rock': 'bar espectaculos',
    'Mad Beer Hall': 'bar espectaculos',
    'Clandestino Café Teatro': 'bar espectaculos',
    'La Cripta Mágica': 'bar espectaculos',
    'Vodevil Circus': 'bar espectaculos',
    'Bala Perdida Club (Hotel Axel Madrid)': 'bar espectaculos',
    'Sleep\'n Atocha': 'bar espectaculos',
    'Sala Houdini': 'bar espectaculos',
    'Sala Galileo Galilei': 'bar espectaculos',
    'Platea Café Teatro': 'club de comedia',
    'Estación Malasaña': 'club de comedia',
    'Abonavida': 'club de comedia',
    'Beer Station': 'club de comedia',
    'El Golfo Comedy Club': 'club de comedia',
    'El Sombrerero Comedy Club': 'club de comedia',
    'Cervecería Valverde Comedy Club': 'club de comedia',
    'Teatro Chocita del Loro - Avenida Brasil': 'club de comedia',
    'Teatro Chocita del Loro - Carabanchel': 'club de comedia',
    'Teatro Chocita del Loro - Gran Vía': 'club de comedia',
    'The Mun': 'espacios variados',
    'Escuela de Danza y Centro Deportivo Belo Art': 'espacios variados',
    'Teatro de las Aguas': 'mini teatro',
    'OFF LATINA': 'mini teatro',
    'La Casa de Rovodorovsky Teatro': 'mini teatro',
    'Cinesa Fuencarral': 'teatro',
    'Cine Palacio de la Prensa': 'teatro',
    'Teatro Príncipe Gran Vía': 'teatro',
    'Teatro Capitol Gran Vía': 'teatro',
    'Teatro Alcázar': 'teatro',
    'Gran teatro Caixabank Príncipe Pío': 'teatro',
    'Teatro Reina Victoria': 'teatro',
    'Teatro Bellas Artes': 'teatro',
    'Teatro Real Carlos III de Aranjuez': 'teatro',
    'Teatro EDP Gran Vía': 'teatro',
    'Teatro Lara': 'teatro',
    'Teatro Amaya': 'teatro',
    'Teatro Victoria Madrid': 'teatro',
    'Teatro Arlequín Gran Vía': 'teatro',
    'Teatros Luchana': 'teatro',
    'Pequeño Teatro Gran Vía de Madrid': 'teatro',
    'Teatro Rey de Pikas': 'teatro'
}

# Aplicar la clasificación utilizando el diccionario
df_locales['tipo_local'] = df_locales['local'].map(clasificacion)
df_locales
# Out:
#                                            local  \
# 0                       Teatro Príncipe Gran Vía
# 1                           El Golfo Comedy Club
# 2                       Teatro Arlequín Gran Vía
# 3                        Teatro Capitol Gran Vía
# 4                              Estación Malasaña
# 5                                 Teatro Alcázar
# 6                              Cinesa Fuencarral
# 7                      El Sombrerero Comedy Club
# 8                            Teatro de las Aguas
# 9                                      Abonavida
# 10                                  Beer Station
# 11                               Teatros Luchana
# 12             Pequeño Teatro Gran Vía de Madrid
# 13                                       The Mun
# 14            Gran teatro Caixabank Príncipe Pío
# 15                                 Estupenda Bar
# 16      Teatro Chocita del Loro - Avenida Brasil
# 17                         Teatro Reina Victoria
# ...

# %% [markdown]
# # 6. Guardamos CSV

# %%
# Especifico la ruta y el nombre del archivo CSV
ruta_archivo_csv = '../01_data/datos_locales_coordenadas.csv'

# Guardo el DataFrame en un archivo CSV
df_locales.to_csv(ruta_archivo_csv, index=False)
